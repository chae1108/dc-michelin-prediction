# %%
import pandas as pd
import bs4, time, csv, math, requests

# %%
yelp_url=pd.read_csv('michelin_list.csv')['Yelp']
yelp_url
# Out:
# 0                https://www.yelp.com/biz/alinea-chicago
# 1               https://www.yelp.com/biz/grace-chicago-3
# 2              https://www.yelp.com/biz/42-grams-chicago
# 3                https://www.yelp.com/biz/acadia-chicago
# 4               https://www.yelp.com/biz/sixteen-chicago
# 5             https://www.yelp.com/biz/blackbird-chicago
# 6                  https://www.yelp.com/biz/boka-chicago
# 7      https://www.yelp.com/biz/duseks-board-and-beer...
# 8            https://www.yelp.com/biz/el-ideas-chicago-2
# 9      https://www.yelp.com/biz/elizabeth-restaurant-...
# 10              https://www.yelp.com/biz/everest-chicago
# 11            https://www.yelp.com/biz/goosefoot-chicago
# 12     https://www.yelp.com/biz/longman-and-eagle-chi...
# 13                 https://www.yelp.com/biz/moto-chicago
# 14                 https://www.yelp.com/biz/naha-chicago
# 15           https://www.yelp.com/biz/north-pond-chicago
# 16            https://www.yelp.com/biz/parachute-chicago
# 17                https://www.yelp.com/biz/schwa-chicago
# 18                https://www.yelp.com/biz/sepia-chicago
# 19           https://www.yelp.com/biz/spiaggia-chicago-4
# 20          https://www.yelp.com/biz/topolobampo-chicago
# 21                  https://www.yelp.com/biz/tru-chicago
# 22     https://www.yelp.com/biz/chefs-table-at-brookl...
# 23     https://www.yelp.com/biz/eleven-madison-park-n...
# 24        https://www.yelp.com/biz/jean-georges-new-york
# 25        https://www.yelp.com/biz/le-bernardin-new-york
# 26                https://www.yelp.com/biz/masa-new-york
# 27              https://www.yelp.com/biz/per-se-new-york
# 28             https://www.yelp.com/biz/aquavit-new-york
# 29               https://www.yelp.com/biz/atera-new-york
#                              ...
# 118        http://www.yelp.com/biz/chez-tj-mountain-view
# 119    http://www.yelp.com/biz/commonwealth-san-franc...
# 120    http://www.yelp.com/biz/farmhouse-inn-restaura...
# 121     http://www.yelp.com/biz/gary-danko-san-francisco
# 122    http://www.yelp.com/biz/keiko-%C3%A0-nob-hill-...
# 123     http://www.yelp.com/biz/kin-khao-san-francisco-2
# 124       http://www.yelp.com/biz/kusakabe-san-francisco
# 125                http://www.yelp.com/biz/la-toque-napa
# 126    http://www.yelp.com/biz/lazy-bear-san-francisco-5
# 127    http://www.yelp.com/biz/lord-stanley-san-franc...
# 128           http://www.yelp.com/biz/luce-san-francisco
# 129    https://www.yelp.com/biz/madrona-manor-healdsb...
# 130    http://www.yelp.com/biz/michael-mina-san-franc...
# 131    http://www.yelp.com/biz/mourad-restaurant-san-...
# 132           http://www.yelp.com/biz/nico-san-francisco
# 133        http://www.yelp.com/biz/octavia-san-francisco
# 134        http://www.yelp.com/biz/omakase-san-francisco
# 135        http://www.yelp.com/biz/plumed-horse-saratoga
# 136              http://www.yelp.com/biz/rasa-burlingame
# 137             http://www.yelp.com/biz/solbar-calistoga
# 138    http://www.yelp.com/biz/sons-and-daughters-san...
# 139           http://www.yelp.com/biz/spqr-san-francisco
# 140         http://www.yelp.com/biz/spruce-san-francisco
# 141    http://www.yelp.com/biz/state-bird-provisions-...
# 142    http://www.yelp.com/biz/sushi-yoshizumi-san-mateo
# 143        https://www.yelp.com/biz/terra-saint-helena-2
# 144    http://www.yelp.com/biz/terrapin-creek-cafe-an...
# 145     http://www.yelp.com/biz/the-village-pub-woodside
# 146    http://www.yelp.com/biz/wako-japanese-restaura...
# 147           http://www.yelp.com/biz/wakuriya-san-mateo
# Name: Yelp, dtype: object

# %%
yelp_url[1]
# Out:
# 'https://www.yelp.com/biz/grace-chicago-3'

# %%
m_url = open('address.csv')
m_url = csv.reader(m_url)
m_url = list(m_url)
m_url = m_url[1:]
m_url
# Out:
# [['https://www.yelp.com/biz/alinea-chicago'],
#  ['https://www.yelp.com/biz/grace-chicago-3'],
#  ['https://www.yelp.com/biz/42-grams-chicago'],
#  ['https://www.yelp.com/biz/acadia-chicago'],
#  ['https://www.yelp.com/biz/sixteen-chicago'],
#  ['https://www.yelp.com/biz/blackbird-chicago'],
#  ['https://www.yelp.com/biz/boka-chicago'],
#  ['https://www.yelp.com/biz/duseks-board-and-beer-chicago-2'],
#  ['https://www.yelp.com/biz/el-ideas-chicago-2'],
#  ['https://www.yelp.com/biz/elizabeth-restaurant-chicago'],
#  ['https://www.yelp.com/biz/everest-chicago'],
#  ['https://www.yelp.com/biz/goosefoot-chicago'],
#  ['https://www.yelp.com/biz/longman-and-eagle-chicago'],
#  ['https://www.yelp.com/biz/moto-chicago'],
#  ['https://www.yelp.com/biz/naha-chicago'],
#  ['https://www.yelp.com/biz/north-pond-chicago'],
#  ['https://www.yelp.com/biz/parachute-chicago'],
#  ['https://www.yelp.com/biz/schwa-chicago'],
#  ['https://www.yelp.com/biz/sepia-chicago'],
#  ['https://www.yelp.com/biz/spiaggia-chicago-4'],
#  ['https://www.yelp.com/biz/topolobampo-chicago'],
#  ['https://www.yelp.com/biz/tru-chicago'],
#  ['https://www.yelp.com/biz/chefs-table-at-brooklyn-fare-brooklyn-3'],
#  ['https://www.yelp.com/biz/eleven-madison-park-new-york'],
#  ['https://www.yelp.com/biz/jean-georges-new-york'],
#  ['https://www.yelp.com/biz/le-bernardin-new-york'],
#  ['https://www.yelp.com/biz/masa-new-york'],
#  ['https://www.yelp.com/biz/per-se-new-york'],
#  ['https://www.yelp.com/biz/aquavit-new-york'],
#  ['https://www.yelp.com/biz/atera-new-york'],
#  ['https://www.yelp.com/biz/blanca-brooklyn'],
#  ['https://www.yelp.com/biz/daniel-new-york-4'],
#  ['https://www.yelp.com/biz/ichimura-at-brushstroke-new-york'],
#  ['https://www.yelp.com/biz/jungsik-new-york'],
#  ['https://www.yelp.com/biz/marea-new-york'],
#  ['https://www.yelp.com/biz/momofuku-ko-new-york-3'],
#  ['https://www.yelp.com/biz/soto-new-york'],
#  ['https://www.yelp.com/biz/the-modern-new-york-3'],
#  ['https://www.yelp.com/biz/ai-fiori-new-york'],
#  ['https://www.yelp.com/biz/aldea-new-york'],
#  ['https://www.yelp.com/biz/andanada-new-york-3'],
#  ['https://www.yelp.com/biz/aureole-new-york'],
#  ['https://www.yelp.com/biz/babbo-new-york'],
#  ['https://www.yelp.com/biz/b%C3%A2tard-new-york'],
#  ['https://www.yelp.com/biz/betony-new-york'],
#  ['https://www.yelp.com/biz/blue-hill-new-york'],
#  ['https://www.yelp.com/biz/bouley-new-york-2'],
#  ['https://www.yelp.com/biz/brushstroke-new-york'],
#  ['https://www.yelp.com/biz/cafe-boulud-new-york-4'],
#  ['https://www.yelp.com/biz/caf%C3%A9-china-new-york-2'],
#  ['https://www.yelp.com/biz/cagen-japan-restaurant-new-york-2'],
#  ['https://www.yelp.com/biz/carbone-new-york'],
#  ['https://www.yelp.com/biz/casa-enrique-long-island-city'],
#  ['https://www.yelp.com/biz/casa-mono-new-york'],
#  ['https://www.yelp.com/biz/caviar-russe-new-york'],
#  ['https://www.yelp.com/biz/del-posto-new-york'],
#  ['https://www.yelp.com/biz/delaware-and-hudson-brooklyn'],
#  ['https://www.yelp.com/biz/dovetail-new-york'],
#  ['https://www.yelp.com/biz/gabriel-kreuther-new-york'],
#  ['https://www.yelp.com/biz/gotham-bar-and-grill-new-york'],
#  ['https://www.yelp.com/biz/gramercy-tavern-new-york'],
#  ['https://www.yelp.com/biz/hirohisa-new-york'],
#  ['https://www.yelp.com/biz/jewel-bako-new-york'],
#  ['https://www.yelp.com/biz/juni-new-york'],
#  ['https://www.yelp.com/biz/junoon-new-york'],
#  ['https://www.yelp.com/biz/kajitsu-new-york-3'],
#  ['https://www.yelp.com/biz/kyo-ya-new-york'],
#  ['https://www.yelp.com/biz/la-vara-brooklyn'],
#  ['https://www.yelp.com/biz/luksus-brooklyn'],
#  ['https://www.yelp.com/biz/m-wells-steakhouse-long-island-city'],
#  ['https://www.yelp.com/biz/meadowsweet-williamsburg'],
#  ['https://www.yelp.com/biz/minetta-tavern-new-york'],
#  ['https://www.yelp.com/biz/the-nomad-restaurant-new-york'],
#  ['https://www.yelp.com/biz/peter-luger-steak-house-brooklyn'],
#  ['https://www.yelp.com/biz/picholine-new-york'],
#  ['https://www.yelp.com/biz/piora-new-york'],
#  ['https://www.yelp.com/biz/pok-pok-ny-brooklyn-3'],
#  ['https://www.yelp.com/biz/public-new-york'],
#  ['https://www.yelp.com/biz/rebelle-new-york'],
#  ['https://www.yelp.com/biz/rosanjin-new-york'],
#  ['https://www.yelp.com/biz/semilla-williamsburg-2'],
#  ['https://www.yelp.com/biz/somtum-der-new-york'],
#  ['https://www.yelp.com/biz/the-spotted-pig-new-york'],
#  ['https://www.yelp.com/biz/sushi-azabu-new-york'],
#  ['https://www.yelp.com/biz/sushi-of-gari-new-york'],
#  ['https://www.yelp.com/biz/sushi-yasuda-new-york'],
#  ['https://www.yelp.com/biz/take-root-brooklyn-3'],
#  ['https://www.yelp.com/biz/telepan-new-york'],
#  ['https://www.yelp.com/biz/tempura-matsui-new-york'],
#  ['https://www.yelp.com/biz/the-breslin-bar-and-dining-room-new-york'],
#  ['https://www.yelp.com/biz/the-finch-clinton-hill'],
#  ['https://www.yelp.com/biz/the-musket-room-new-york'],
#  ['https://www.yelp.com/biz/the-river-caf%C3%A9-brooklyn-3'],
#  ['https://www.yelp.com/biz/torishin-new-york-3'],
#  ['https://www.yelp.com/biz/tulsi-new-york'],
#  ['https://www.yelp.com/biz/uncle-boons-new-york-2'],
#  ['https://www.yelp.com/biz/walls%C3%A9-new-york-2'],
#  ['https://www.yelp.com/biz/zzs-clam-bar-new-york'],
#  ['http://www.yelp.com/biz/benu-san-francisco-4'],
#  ['http://www.yelp.com/biz/the-french-laundry-yountville-2'],
#  ['http://www.yelp.com/biz/manresa-los-gatos-2'],
#  ['http://www.yelp.com/biz/the-restaurant-at-meadowood-st-helena'],
#  ['http://www.yelp.com/biz/saison-san-francisco-2'],
#  ['http://www.yelp.com/biz/acquerello-san-francisco'],
#  ['http://www.yelp.com/biz/atelier-crenn-san-francisco'],
#  ['http://www.yelp.com/biz/baum%C3%A9-palo-alto-5'],
#  ['http://www.yelp.com/biz/campton-place-restaurant-san-francisco'],
#  ['http://www.yelp.com/biz/coi-san-francisco'],
#  ['http://www.yelp.com/biz/commis-oakland-2'],
#  ['http://www.yelp.com/biz/quince-san-francisco'],
#  ['http://www.yelp.com/biz/all-spice-san-francisco'],
#  ['http://www.yelp.com/biz/als-place-san-francisco'],
#  ['http://www.yelp.com/biz/ame-san-francisco'],
#  ['http://www.yelp.com/biz/aster-san-francisco'],
#  ['https://www.yelp.com/biz/auberge-du-soleil-restaurant-rutherford'],
#  ['http://www.yelp.com/biz/aziza-san-francisco'],
#  ['http://www.yelp.com/biz/bouchon-yountville'],
#  ['http://www.yelp.com/biz/californios-san-francisco'],
#  ['http://www.yelp.com/biz/chez-tj-mountain-view'],
#  ['http://www.yelp.com/biz/commonwealth-san-francisco'],
#  ['http://www.yelp.com/biz/farmhouse-inn-restaurant-forestville-2'],
#  ['http://www.yelp.com/biz/gary-danko-san-francisco'],
#  ['http://www.yelp.com/biz/keiko-%C3%A0-nob-hill-san-francisco-2'],
#  ['http://www.yelp.com/biz/kin-khao-san-francisco-2'],
#  ['http://www.yelp.com/biz/kusakabe-san-francisco'],
#  ['http://www.yelp.com/biz/la-toque-napa'],
#  ['http://www.yelp.com/biz/lazy-bear-san-francisco-5'],
#  ['http://www.yelp.com/biz/lord-stanley-san-francisco'],
#  ['http://www.yelp.com/biz/luce-san-francisco'],
#  ['https://www.yelp.com/biz/madrona-manor-healdsburg-2'],
#  ['http://www.yelp.com/biz/michael-mina-san-francisco-2'],
#  ['http://www.yelp.com/biz/mourad-restaurant-san-francisco'],
#  ['http://www.yelp.com/biz/nico-san-francisco'],
#  ['http://www.yelp.com/biz/octavia-san-francisco'],
#  ['http://www.yelp.com/biz/omakase-san-francisco'],
#  ['http://www.yelp.com/biz/plumed-horse-saratoga'],
#  ['http://www.yelp.com/biz/rasa-burlingame'],
#  ['http://www.yelp.com/biz/solbar-calistoga'],
#  ['http://www.yelp.com/biz/sons-and-daughters-san-francisco'],
#  ['http://www.yelp.com/biz/spqr-san-francisco'],
#  ['http://www.yelp.com/biz/spruce-san-francisco'],
#  ['http://www.yelp.com/biz/state-bird-provisions-san-francisco'],
#  ['http://www.yelp.com/biz/sushi-yoshizumi-san-mateo'],
#  ['https://www.yelp.com/biz/terra-saint-helena-2'],
#  ['http://www.yelp.com/biz/terrapin-creek-cafe-and-restaurant-bodega-bay'],
#  ['http://www.yelp.com/biz/the-village-pub-woodside'],
#  ['http://www.yelp.com/biz/wako-japanese-restaurant-san-francisco'],
#  ['http://www.yelp.com/biz/wakuriya-san-mateo']]

# %%
m_url
# Out:
# [['Alinea', 'https://www.yelp.com/biz/alinea-chicago', '3', 'CH'],
#  ['Grace', 'https://www.yelp.com/biz/grace-chicago-3', '3', 'CH'],
#  ['42 Grams', 'https://www.yelp.com/biz/42-grams-chicago', '2', 'CH'],
#  ['Acadia', 'https://www.yelp.com/biz/acadia-chicago', '2', 'CH'],
#  ['Sixteen', 'https://www.yelp.com/biz/sixteen-chicago', '2', 'CH'],
#  ['Blackbird', 'https://www.yelp.com/biz/blackbird-chicago', '1', 'CH'],
#  ['Boka', 'https://www.yelp.com/biz/boka-chicago', '1', 'CH'],
#  ['Dusek\x92s (Board & Beer)',
#   'https://www.yelp.com/biz/duseks-board-and-beer-chicago-2',
#   '1',
#   'CH'],
#  ['EL Ideas', 'https://www.yelp.com/biz/el-ideas-chicago-2', '1', 'CH'],
#  ['Elizabeth',
#   'https://www.yelp.com/biz/elizabeth-restaurant-chicago',
#   '1',
#   'CH'],
#  ['Everest', 'https://www.yelp.com/biz/everest-chicago', '1', 'CH'],
#  ['Goosefoot', 'https://www.yelp.com/biz/goosefoot-chicago', '1', 'CH'],
#  ['Longman & Eagle',
#   'https://www.yelp.com/biz/longman-and-eagle-chicago',
#   '1',
#   'CH'],
#  ['Moto', 'https://www.yelp.com/biz/moto-chicago', '1', 'CH'],
#  ['NAHA', 'https://www.yelp.com/biz/naha-chicago', '1', 'CH'],
#  ['North Pond', 'https://www.yelp.com/biz/north-pond-chicago', '1', 'CH'],
#  ['Parachute', 'https://www.yelp.com/biz/parachute-chicago', '1', 'CH'],
#  ['Schwa', 'https://www.yelp.com/biz/schwa-chicago', '1', 'CH'],
#  ['Sepia', 'https://www.yelp.com/biz/sepia-chicago', '1', 'CH'],
#  ['Spiaggia', 'https://www.yelp.com/biz/spiaggia-chicago-4', '1', 'CH'],
#  ['Topolobampo', 'https://www.yelp.com/biz/topolobampo-chicago', '1', 'CH'],
#  ['Tru', 'https://www.yelp.com/biz/tru-chicago', '1', 'CH'],
#  ["Chef's Table at Brooklyn Fare",
#   'https://www.yelp.com/biz/chefs-table-at-brooklyn-fare-brooklyn-3',
#   '3',
#   'NY'],
#  ['Eleven Madison Park',
#   'https://www.yelp.com/biz/eleven-madison-park-new-york',
#   '3',
#   'NY'],
#  ['Jean-Georges', 'https://www.yelp.com/biz/jean-georges-new-york', '3', 'NY'],
#  ['Le Bernardin', 'https://www.yelp.com/biz/le-bernardin-new-york', '3', 'NY'],
#  ['Masa', 'https://www.yelp.com/biz/masa-new-york', '3', 'NY'],
#  ['Per Se', 'https://www.yelp.com/biz/per-se-new-york', '3', 'NY'],
#  ['Aquavit', 'https://www.yelp.com/biz/aquavit-new-york', '2', 'NY'],
#  ['Atera', 'https://www.yelp.com/biz/atera-new-york', '2', 'NY'],
#  ['Blanca', 'https://www.yelp.com/biz/blanca-brooklyn', '2', 'NY'],
#  ['Daniel', 'https://www.yelp.com/biz/daniel-new-york-4', '2', 'NY'],
#  ['Ichimura',
#   'https://www.yelp.com/biz/ichimura-at-brushstroke-new-york',
#   '2',
#   'NY'],
#  ['Jungsik', 'https://www.yelp.com/biz/jungsik-new-york', '2', 'NY'],
#  ['Marea', 'https://www.yelp.com/biz/marea-new-york', '2', 'NY'],
#  ['Momofuku Ko', 'https://www.yelp.com/biz/momofuku-ko-new-york-3', '2', 'NY'],
#  ['Soto', 'https://www.yelp.com/biz/soto-new-york', '2', 'NY'],
#  ['The Modern', 'https://www.yelp.com/biz/the-modern-new-york-3', '2', 'NY'],
#  ['Ai Fiori', 'https://www.yelp.com/biz/ai-fiori-new-york', '1', 'NY'],
#  ['Aldea', 'https://www.yelp.com/biz/aldea-new-york', '1', 'NY'],
#  ['Andanada', 'https://www.yelp.com/biz/andanada-new-york-3', '1', 'NY'],
#  ['Aureole', 'https://www.yelp.com/biz/aureole-new-york', '1', 'NY'],
#  ['Babbo', 'https://www.yelp.com/biz/babbo-new-york', '1', 'NY'],
#  ['B\xe2tard', 'https://www.yelp.com/biz/b%C3%A2tard-new-york', '1', 'NY'],
#  ['Betony', 'https://www.yelp.com/biz/betony-new-york', '1', 'NY'],
#  ['Blue Hill', 'https://www.yelp.com/biz/blue-hill-new-york', '1', 'NY'],
#  ['Bouley', 'https://www.yelp.com/biz/bouley-new-york-2', '1', 'NY'],
#  ['Brushstroke', 'https://www.yelp.com/biz/brushstroke-new-york', '1', 'NY'],
#  ['Caf\xe9 Boulud',
#   'https://www.yelp.com/biz/cafe-boulud-new-york-4',
#   '1',
#   'NY'],
#  ['Caf\xe9 China',
#   'https://www.yelp.com/biz/caf%C3%A9-china-new-york-2',
#   '1',
#   'NY'],
#  ['Cagen',
#   'https://www.yelp.com/biz/cagen-japan-restaurant-new-york-2',
#   '1',
#   'NY'],
#  ['Carbone', 'https://www.yelp.com/biz/carbone-new-york', '1', 'NY'],
#  ['Casa Enr\xedque',
#   'https://www.yelp.com/biz/casa-enrique-long-island-city',
#   '1',
#   'NY'],
#  ['Casa Mono', 'https://www.yelp.com/biz/casa-mono-new-york', '1', 'NY'],
#  ['Caviar Russe', 'https://www.yelp.com/biz/caviar-russe-new-york', '1', 'NY'],
#  ['Del Posto', 'https://www.yelp.com/biz/del-posto-new-york', '1', 'NY'],
#  ['Delaware and Hudson',
#   'https://www.yelp.com/biz/delaware-and-hudson-brooklyn',
#   '1',
#   'NY'],
#  ['Dovetail', 'https://www.yelp.com/biz/dovetail-new-york', '1', 'NY'],
#  ['Gabriel Kreuther',
#   'https://www.yelp.com/biz/gabriel-kreuther-new-york',
#   '1',
#   'NY'],
#  ['Gotham Bar and Grill',
#   'https://www.yelp.com/biz/gotham-bar-and-grill-new-york',
#   '1',
#   'NY'],
#  ['Gramercy Tavern',
#   'https://www.yelp.com/biz/gramercy-tavern-new-york',
#   '1',
#   'NY'],
#  ['Hirohisa', 'https://www.yelp.com/biz/hirohisa-new-york', '1', 'NY'],
#  ['Jewel Bako', 'https://www.yelp.com/biz/jewel-bako-new-york', '1', 'NY'],
#  ['Juni', 'https://www.yelp.com/biz/juni-new-york', '1', 'NY'],
#  ['Junoon', 'https://www.yelp.com/biz/junoon-new-york', '1', 'NY'],
#  ['Kajitsu', 'https://www.yelp.com/biz/kajitsu-new-york-3', '1', 'NY'],
#  ['Kyo Ya', 'https://www.yelp.com/biz/kyo-ya-new-york', '1', 'NY'],
#  ['La Vara', 'https://www.yelp.com/biz/la-vara-brooklyn', '1', 'NY'],
#  ['Luksus at T\xf8rst', 'https://www.yelp.com/biz/luksus-brooklyn', '1', 'NY'],
#  ['M. Wells Steakhouse',
#   'https://www.yelp.com/biz/m-wells-steakhouse-long-island-city',
#   '1',
#   'NY'],
#  ['Meadowsweet',
#   'https://www.yelp.com/biz/meadowsweet-williamsburg',
#   '1',
#   'NY'],
#  ['Minetta Tavern',
#   'https://www.yelp.com/biz/minetta-tavern-new-york',
#   '1',
#   'NY'],
#  ['NoMad',
#   'https://www.yelp.com/biz/the-nomad-restaurant-new-york',
#   '1',
#   'NY'],
#  ['Peter Luger',
#   'https://www.yelp.com/biz/peter-luger-steak-house-brooklyn',
#   '1',
#   'NY'],
#  ['Picholine', 'https://www.yelp.com/biz/picholine-new-york', '1', 'NY'],
#  ['Piora', 'https://www.yelp.com/biz/piora-new-york', '1', 'NY'],
#  ['Pok Pok Ny', 'https://www.yelp.com/biz/pok-pok-ny-brooklyn-3', '1', 'NY'],
#  ['Public', 'https://www.yelp.com/biz/public-new-york', '1', 'NY'],
#  ['Rebelle', 'https://www.yelp.com/biz/rebelle-new-york', '1', 'NY'],
#  ['Rosanjin', 'https://www.yelp.com/biz/rosanjin-new-york', '1', 'NY'],
#  ['Semilla', 'https://www.yelp.com/biz/semilla-williamsburg-2', '1', 'NY'],
#  ['Somtum Der', 'https://www.yelp.com/biz/somtum-der-new-york', '1', 'NY'],
#  ['Spotted Pig',
#   'https://www.yelp.com/biz/the-spotted-pig-new-york',
#   '1',
#   'NY'],
#  ['Sushi Azabu', 'https://www.yelp.com/biz/sushi-azabu-new-york', '1', 'NY'],
#  ['Sushi of Gari',
#   'https://www.yelp.com/biz/sushi-of-gari-new-york',
#   '1',
#   'NY'],
#  ['Sushi Yasuda', 'https://www.yelp.com/biz/sushi-yasuda-new-york', '1', 'NY'],
#  ['Take Root', 'https://www.yelp.com/biz/take-root-brooklyn-3', '1', 'NY'],
#  ['Telepan', 'https://www.yelp.com/biz/telepan-new-york', '1', 'NY'],
#  ['Tempura Matsui',
#   'https://www.yelp.com/biz/tempura-matsui-new-york',
#   '1',
#   'NY'],
#  ['The Breslin',
#   'https://www.yelp.com/biz/the-breslin-bar-and-dining-room-new-york',
#   '1',
#   'NY'],
#  ['The Finch', 'https://www.yelp.com/biz/the-finch-clinton-hill', '1', 'NY'],
#  ['The Musket Room',
#   'https://www.yelp.com/biz/the-musket-room-new-york',
#   '1',
#   'NY'],
#  ['The River Caf\xe9',
#   'https://www.yelp.com/biz/the-river-caf%C3%A9-brooklyn-3',
#   '1',
#   'NY'],
#  ['Tori Shin', 'https://www.yelp.com/biz/torishin-new-york-3', '1', 'NY'],
#  ['Tulsi', 'https://www.yelp.com/biz/tulsi-new-york', '1', 'NY'],
#  ['Uncle Boons', 'https://www.yelp.com/biz/uncle-boons-new-york-2', '1', 'NY'],
#  ['Walls\xe9', 'https://www.yelp.com/biz/walls%C3%A9-new-york-2', '1', 'NY'],
#  ['ZZ\x92s Clam Bar',
#   'https://www.yelp.com/biz/zzs-clam-bar-new-york',
#   '1',
#   'NY'],
#  ['Benu', 'http://www.yelp.com/biz/benu-san-francisco-4', '3', 'SF'],
#  ['French Laundry',
#   'http://www.yelp.com/biz/the-french-laundry-yountville-2',
#   '3',
#   'SF'],
#  ['Manresa', 'http://www.yelp.com/biz/manresa-los-gatos-2', '3', 'SF'],
#  ['Restaurant at Meadowood',
#   'http://www.yelp.com/biz/the-restaurant-at-meadowood-st-helena',
#   '3',
#   'SF'],
#  ['Saison', 'http://www.yelp.com/biz/saison-san-francisco-2', '3', 'SF'],
#  ['Acquerello', 'http://www.yelp.com/biz/acquerello-san-francisco', '2', 'SF'],
#  ['Atelier Crenn',
#   'http://www.yelp.com/biz/atelier-crenn-san-francisco',
#   '2',
#   'SF'],
#  ['Baum\xe9', 'http://www.yelp.com/biz/baum%C3%A9-palo-alto-5', '2', 'SF'],
#  ['Campton Place',
#   'http://www.yelp.com/biz/campton-place-restaurant-san-francisco',
#   '2',
#   'SF'],
#  ['Coi', 'http://www.yelp.com/biz/coi-san-francisco', '2', 'SF'],
#  ['Commis', 'http://www.yelp.com/biz/commis-oakland-2', '2', 'SF'],
#  ['Quince', 'http://www.yelp.com/biz/quince-san-francisco', '2', 'SF'],
#  ['All Spice', 'http://www.yelp.com/biz/all-spice-san-francisco', '1', 'SF'],
#  ["Al's Place", 'http://www.yelp.com/biz/als-place-san-francisco', '1', 'SF'],
#  ['Ame', 'http://www.yelp.com/biz/ame-san-francisco', '1', 'SF'],
#  ['Aster', 'http://www.yelp.com/biz/aster-san-francisco', '1', 'SF'],
#  ['Auberge du Soleil',
#   'https://www.yelp.com/biz/auberge-du-soleil-restaurant-rutherford',
#   '1',
#   'SF'],
#  ['Aziza', 'http://www.yelp.com/biz/aziza-san-francisco', '1', 'SF'],
#  ['Bouchon', 'http://www.yelp.com/biz/bouchon-yountville', '1', 'SF'],
#  ['Californios',
#   'http://www.yelp.com/biz/californios-san-francisco',
#   '1',
#   'SF'],
#  ['Chez TJ', 'http://www.yelp.com/biz/chez-tj-mountain-view', '1', 'SF'],
#  ['Commonwealth',
#   'http://www.yelp.com/biz/commonwealth-san-francisco',
#   '1',
#   'SF'],
#  ['Farmhouse Inn & Restaurant',
#   'http://www.yelp.com/biz/farmhouse-inn-restaurant-forestville-2',
#   '1',
#   'SF'],
#  ['Gary Danko', 'http://www.yelp.com/biz/gary-danko-san-francisco', '1', 'SF'],
#  ['Keiko \xe0 Nob Hill',
#   'http://www.yelp.com/biz/keiko-%C3%A0-nob-hill-san-francisco-2',
#   '1',
#   'SF'],
#  ['Kin Khao', 'http://www.yelp.com/biz/kin-khao-san-francisco-2', '1', 'SF'],
#  ['Kusakabe', 'http://www.yelp.com/biz/kusakabe-san-francisco', '1', 'SF'],
#  ['La Toque', 'http://www.yelp.com/biz/la-toque-napa', '1', 'SF'],
#  ['Lazy Bear', 'http://www.yelp.com/biz/lazy-bear-san-francisco-5', '1', 'SF'],
#  ['Lord Stanley',
#   'http://www.yelp.com/biz/lord-stanley-san-francisco',
#   '1',
#   'SF'],
#  ['Luce', 'http://www.yelp.com/biz/luce-san-francisco', '1', 'SF'],
#  ['Madrona Manor',
#   'https://www.yelp.com/biz/madrona-manor-healdsburg-2',
#   '1',
#   'SF'],
#  ['Michael Mina',
#   'http://www.yelp.com/biz/michael-mina-san-francisco-2',
#   '1',
#   'SF'],
#  ['Mourad',
#   'http://www.yelp.com/biz/mourad-restaurant-san-francisco',
#   '1',
#   'SF'],
#  ['Nico', 'http://www.yelp.com/biz/nico-san-francisco', '1', 'SF'],
#  ['Octavia', 'http://www.yelp.com/biz/octavia-san-francisco', '1', 'SF'],
#  ['Omakase', 'http://www.yelp.com/biz/omakase-san-francisco', '1', 'SF'],
#  ['Plumed', 'http://www.yelp.com/biz/plumed-horse-saratoga', '1', 'SF'],
#  ['Rasa', 'http://www.yelp.com/biz/rasa-burlingame', '1', 'SF'],
#  ['Solbar', 'http://www.yelp.com/biz/solbar-calistoga', '1', 'SF'],
#  ['Sons & Daughters',
#   'http://www.yelp.com/biz/sons-and-daughters-san-francisco',
#   '1',
#   'SF'],
#  ['SPQR', 'http://www.yelp.com/biz/spqr-san-francisco', '1', 'SF'],
#  ['Spruce', 'http://www.yelp.com/biz/spruce-san-francisco', '1', 'SF'],
#  ['State Bird Provisions',
#   'http://www.yelp.com/biz/state-bird-provisions-san-francisco',
#   '1',
#   'SF'],
#  ['Sushi Yoshizumi',
#   'http://www.yelp.com/biz/sushi-yoshizumi-san-mateo',
#   '1',
#   'SF'],
#  ['Terra', 'https://www.yelp.com/biz/terra-saint-helena-2', '1', 'SF'],
#  ['Terrapin Creek',
#   'http://www.yelp.com/biz/terrapin-creek-cafe-and-restaurant-bodega-bay',
#   '1',
#   'SF'],
#  ['Village Pub',
#   'http://www.yelp.com/biz/the-village-pub-woodside',
#   '1',
#   'SF'],
#  ['Wako',
#   'http://www.yelp.com/biz/wako-japanese-restaurant-san-francisco',
#   '1',
#   'SF'],
#  ['Wakuriya', 'http://www.yelp.com/biz/wakuriya-san-mateo', '1', 'SF']]

# %%
def get_restaurant_data(d):

    r_dict = {}
    restaurant_name = 'Unknown' if d.select('h1.biz-page-title.embossed-text-white')[0].string is None else\
    d.select('h1.biz-page-title.embossed-text-white')[0].string.encode('ascii','ignore').strip()
    
    overall_rating = 'Unknown' if d.find_all('meta', {'itemprop': 'ratingValue'})[0].get('content') is None else\
    d.find_all('meta', {'itemprop': 'ratingValue'})[0].get('content')
    
    total_reviews = 'Unknown' if d.find_all('span', {'itemprop': 'reviewCount'})[0].string is None else\
    d.find_all('span', {'itemprop': 'reviewCount'})[0].string
    
    price_range = 'Unknown' if d.find_all('span', {'class': 'business-attribute price-range'})[0].string is None else\
    d.find_all('span', {'class': 'business-attribute price-range'})[0].string.encode('ascii','ignore')
    
    range_name = 'Unknown' if d.find_all('dd', {'class': 'nowrap price-description'})[0].string is None else\
    d.find_all('dd', {'class': 'nowrap price-description'})[0].string.encode('ascii','ignore').strip()
    
    address_street = 'Unknown' if d.find_all('span', {'itemprop': 'streetAddress'})[0].string is None else\
    d.find_all('span', {'itemprop': 'streetAddress'})[0].string.encode('ascii','ignore')
    
    address_city = 'Unknown' if d.find_all('span', {'itemprop': 'addressLocality'})[0].string is None else\
    d.find_all('span', {'itemprop': 'addressLocality'})[0].string.encode('ascii','ignore')
    
    address_state = 'Unknown' if d.find_all('span', {'itemprop': 'addressRegion'})[0].string is None else\
    d.find_all('span', {'itemprop': 'addressRegion'})[0].string.encode('ascii','ignore')
    
    address_zip = 'Unknown' if d.find_all('span', {'itemprop': 'postalCode'})[0].string is None else\
    d.find_all('span', {'itemprop': 'postalCode'})[0].string.encode('ascii','ignore')

    r_dict['restaurant_name'] = restaurant_name
    r_dict['review_rating'] = overall_rating
    r_dict['total_reviews'] = total_reviews
    r_dict['price_range'] = price_range
    r_dict['range_name'] = range_name
    r_dict['address_street'] = address_street
    r_dict['address_city'] = address_city
    r_dict['address_state'] = address_state
    r_dict['address_zip'] = address_zip

    return r_dict

# %%
michelin_rest_scrape = []

# %%
def url_cycle(u_file, p = 0):
    rest_list = []
    rev_list = []
    for i in u_file:
        try:
            f = bs4.BeautifulSoup(requests.get(i[0]).text)
            r = get_restaurant_data(f)
            total_review_count = int(r['total_reviews'])
            pages = range(0,total_review_count,20) # this is missing first page, url of 0 doesn't work
            print i
            rest_list.append(r)
            time.sleep(2)
        except Exception as e:
            print i
            print e
            print '_'*60
            pass
            
        for j in pages[p:len(pages)+1]:
            try:
                d = bs4.BeautifulSoup(requests.get(str(i[0])+'?sort_by=date_desc&start='+str(j)).text)
                rv = get_review_data(d)
#                 print rv
                print j
                rev_list.append(rv)
                time.sleep(4)
            except Exception as e2:
                print 'i = ' + str(i)
                print 'j = ' + str(j)
                print e2
                print '_'*60
                pass
            
    return rest_list #rev_list #, rev_list

# %%
michelin_rest_scrape.append(url_cycle(m_url[4:5]))
# Out:
# ['https://www.yelp.com/biz/sixteen-chicago']
# list index out of range
# ____________________________________________________________

# %%
michelin_rest_scrape
# Out:
# [[{'address_city': 'Chicago',
#    'address_state': 'IL',
#    'address_street': '1723 N Halsted St',
#    'address_zip': '60614',
#    'price_range': '$$$$',
#    'range_name': 'Above $61',
#    'restaurant_name': 'Alinea',
#    'review_rating': '4.5',
#    'total_reviews': u'1541'},
#   {'address_city': 'Chicago',
#    'address_state': 'IL',
#    'address_street': '652 W Randolph St',
#    'address_zip': '60661',
#    'price_range': '$$$$',
#    'range_name': 'Above $61',
#    'restaurant_name': 'Grace',
#    'review_rating': '4.5',
#    'total_reviews': u'234'},
#   {'address_city': 'Chicago',
#    'address_state': 'IL',
#    'address_street': '4662 N Broadway',
#    'address_zip': '60640',
#    'price_range': '$$$$',
#    'range_name': 'Above $61',
#    'restaurant_name': '42 grams',
#    'review_rating': '4.5',
#    'total_reviews': u'65'}]]

# %%
flattened_list = []
for x in michelin_rest_scrape:
    for y in x:
        flattened_list.append(y)
new_flattened_list = []
for x in flattened_list:
    new_flattened_list.append(y.values())
print new_flattened_list
# Out:
# [['Chicago', 'Above $61', '4.5', '42 grams', 'IL', u'65', '$$$$', '4662 N Broadway', '60640'], ['Chicago', 'Above $61', '4.5', '42 grams', 'IL', u'65', '$$$$', '4662 N Broadway', '60640'], ['Chicago', 'Above $61', '4.5', '42 grams', 'IL', u'65', '$$$$', '4662 N Broadway', '60640']]

# %%
df=pd.DataFrame(new_flattened_list)
df.head()
# Out:
#          0          1    2         3   4   5     6                7      8
# 0  Chicago  Above $61  4.5  42 grams  IL  65  $$$$  4662 N Broadway  60640
# 1  Chicago  Above $61  4.5  42 grams  IL  65  $$$$  4662 N Broadway  60640
# 2  Chicago  Above $61  4.5  42 grams  IL  65  $$$$  4662 N Broadway  60640

# %%
df[6][0]
# Out:
# '$$$$'
